# %%
import pandas as pd

# %%
df2 = pd.read_csv('../Covid_19/data/CF_dataset.txt', header=None, sep='_', error_bad_lines=False)
# Out:
# b'Skipping line 936: expected 348 fields, saw 352\nSkipping line 963: expected 348 fields, saw 364\nSkipping line 970: expected 348 fields, saw 360\n'

# %%
df2
# Out:
#                       0    1       2     3    \
# 0        Patient 1\tUnion   81    Male  36.6
# 1        Patient 2\tUnion   50    Male  38.7
# 2        Patient 3\tUnion   65  Female  38.5
# 3        Patient 4\tUnion   73    Male  38.5
# 4        Patient 5\tUnion   64  Female  38.0
# ...                   ...  ...     ...   ...
# 1513  Patient 1517\tUnion   45  Female  38.9
# 1514  Patient 1518\tUnion   66  Female  36.6
# 1515  Patient 1519\tUnion   71  Female  36.6
# 1516  Patient 1520\tUnion   66  Female  36.6
# 1517  Patient 1521\tUnion   64  Female  36.6
#
#                                                     4         5         6    \
# 0                           Hypertension, Thyroidectomy  Positive  Positive
# 1                                                    No  Positive  Positive
# 2                         Postoperative cervical cancer  Positive  Positive
# 3                                   Aorta calcification  Positive  Positive
# ...

# %%
df2.iloc[:,1:90]
# Out:
#       1       2     3                                                  4   \
# 0     81    Male  36.6                        Hypertension, Thyroidectomy
# 1     50    Male  38.7                                                 No
# 2     65  Female  38.5                      Postoperative cervical cancer
# 3     73    Male  38.5                                Aorta calcification
# 4     64  Female  38.0                                                 No
# ...   ..     ...   ...                                                ...
# 1513  45  Female  38.9                           Fatty liver, Hepatitis B
# 1514  66  Female  36.6                                                 No
# 1515  71  Female  36.6                  Hypertension, Atrial fibrillation
# 1516  66  Female  36.6                                                 No
# 1517  64  Female  36.6  Hypertension, Coronary atherosclerotic heart d...
#
#             5         6        7                           8   \
# ...

# %%
df3 = df2.iloc[:,:]

# %%
#df3.columns = ["Hospital", "Age", "Gender", "Body temperature", "Underlying diseases", "SARS-CoV-2 nucleic acids", "Computed tomography (CT)", "Morbidity outcome", "Mortality outcome"]

# %%
df3
# Out:
#                       0    1       2     3    \
# 0        Patient 1\tUnion   81    Male  36.6
# 1        Patient 2\tUnion   50    Male  38.7
# 2        Patient 3\tUnion   65  Female  38.5
# 3        Patient 4\tUnion   73    Male  38.5
# 4        Patient 5\tUnion   64  Female  38.0
# ...                   ...  ...     ...   ...
# 1513  Patient 1517\tUnion   45  Female  38.9
# 1514  Patient 1518\tUnion   66  Female  36.6
# 1515  Patient 1519\tUnion   71  Female  36.6
# 1516  Patient 1520\tUnion   66  Female  36.6
# 1517  Patient 1521\tUnion   64  Female  36.6
#
#                                                     4         5         6    \
# 0                           Hypertension, Thyroidectomy  Positive  Positive
# 1                                                    No  Positive  Positive
# 2                         Postoperative cervical cancer  Positive  Positive
# 3                                   Aorta calcification  Positive  Positive
# ...

# %%
df3[0]
# Out:
# 0          Patient 1\tUnion
# 1          Patient 2\tUnion
# 2          Patient 3\tUnion
# 3          Patient 4\tUnion
# 4          Patient 5\tUnion
#                ...
# 1513    Patient 1517\tUnion
# 1514    Patient 1518\tUnion
# 1515    Patient 1519\tUnion
# 1516    Patient 1520\tUnion
# 1517    Patient 1521\tUnion
# Name: 0, Length: 1518, dtype: object

# %%
new = df3.iloc[:,0].str.split("\t", n = 1, expand = True)
new
# Out:
#                  0      1
# 0        Patient 1  Union
# 1        Patient 2  Union
# 2        Patient 3  Union
# 3        Patient 4  Union
# 4        Patient 5  Union
# ...            ...    ...
# 1513  Patient 1517  Union
# 1514  Patient 1518  Union
# 1515  Patient 1519  Union
# 1516  Patient 1520  Union
# 1517  Patient 1521  Union
#
# [1518 rows x 2 columns]

# %%
df3["Patient"]= new[0]

# %%
df3["Hospital Name"]= new[1]

# %%
df3 = df3.drop(df3.columns[0], axis=1)
df3
# Out:
#        1       2     3                                                  4  \
# 0     81    Male  36.6                        Hypertension, Thyroidectomy
# 1     50    Male  38.7                                                 No
# 2     65  Female  38.5                      Postoperative cervical cancer
# 3     73    Male  38.5                                Aorta calcification
# 4     64  Female  38.0                                                 No
# ...   ..     ...   ...                                                ...
# 1513  45  Female  38.9                           Fatty liver, Hepatitis B
# 1514  66  Female  36.6                                                 No
# 1515  71  Female  36.6                  Hypertension, Atrial fibrillation
# 1516  66  Female  36.6                                                 No
# 1517  64  Female  36.6  Hypertension, Coronary atherosclerotic heart d...
#
#              5         6        7                           8  \
# ...

# %%
cols = list(df3.columns)
cols = [cols[-1]] + cols[:-1]
df3 = df3[cols]

# %%
df3
# Out:
#      Hospital Name   1       2     3  \
# 0            Union  81    Male  36.6
# 1            Union  50    Male  38.7
# 2            Union  65  Female  38.5
# 3            Union  73    Male  38.5
# 4            Union  64  Female  38.0
# ...            ...  ..     ...   ...
# 1513         Union  45  Female  38.9
# 1514         Union  66  Female  36.6
# 1515         Union  71  Female  36.6
# 1516         Union  66  Female  36.6
# 1517         Union  64  Female  36.6
#
#                                                       4         5         6  \
# 0                           Hypertension, Thyroidectomy  Positive  Positive
# 1                                                    No  Positive  Positive
# 2                         Postoperative cervical cancer  Positive  Positive
# 3                                   Aorta calcification  Positive  Positive
# 4                                                    No  Positive  Positive
# ...

# %%
cols = list(df3.columns)
cols = [cols[-1]] + cols[:-1]
df3 = df3[cols]

# %%
df3
# Out:
#            Patient Hospital Name   1       2     3  \
# 0        Patient 1         Union  81    Male  36.6
# 1        Patient 2         Union  50    Male  38.7
# 2        Patient 3         Union  65  Female  38.5
# 3        Patient 4         Union  73    Male  38.5
# 4        Patient 5         Union  64  Female  38.0
# ...            ...           ...  ..     ...   ...
# 1513  Patient 1517         Union  45  Female  38.9
# 1514  Patient 1518         Union  66  Female  36.6
# 1515  Patient 1519         Union  71  Female  36.6
# 1516  Patient 1520         Union  66  Female  36.6
# 1517  Patient 1521         Union  64  Female  36.6
#
#                                                       4         5         6  \
# 0                           Hypertension, Thyroidectomy  Positive  Positive
# 1                                                    No  Positive  Positive
# 2                         Postoperative cervical cancer  Positive  Positive
# ...

# %%
#df3.columns = ["Hospital", "Age", "Gender", "Body temperature", "Underlying diseases", "SARS-CoV-2 nucleic acids", "Computed tomography (CT)", "Morbidity outcome", "Mortality outcome"]

# %%
df3.rename(columns={df3.columns[2]: "Age", df3.columns[3]: "Gender", df3.columns[4]: "Body temperature", df3.columns[5]: "Underlying diseases", df3.columns[6]: "SARS-CoV-2 nucleic acids", df3.columns[7]: "Computed tomography (CT)", df3.columns[8]: "Morbidity outcome", df3.columns[9]: "Mortality outcome"}, inplace = True)

# %%
df3
# Out:
#            Patient Hospital Name  Age  Gender  Body temperature  \
# 0        Patient 1         Union   81    Male              36.6
# 1        Patient 2         Union   50    Male              38.7
# 2        Patient 3         Union   65  Female              38.5
# 3        Patient 4         Union   73    Male              38.5
# 4        Patient 5         Union   64  Female              38.0
# ...            ...           ...  ...     ...               ...
# 1513  Patient 1517         Union   45  Female              38.9
# 1514  Patient 1518         Union   66  Female              36.6
# 1515  Patient 1519         Union   71  Female              36.6
# 1516  Patient 1520         Union   66  Female              36.6
# 1517  Patient 1521         Union   64  Female              36.6
#
#                                     Underlying diseases  \
# 0                           Hypertension, Thyroidectomy
# 1                                                    No
# ...

# %%
new2 = df3.iloc[:,9].str.split(" ", n = 1, expand = True)
new2
# Out:
#             0                   1
# 0       Cured  Routine Blood Test
# 1       Cured  Routine Blood Test
# 2       Cured  Routine Blood Test
# 3       Cured  Routine Blood Test
# 4       Cured  Routine Blood Test
# ...       ...                 ...
# 1513  Unknown  Routine Blood Test
# 1514  Unknown  Routine Blood Test
# 1515    Cured  Routine Blood Test
# 1516    Cured  Routine Blood Test
# 1517    Cured  Routine Blood Test
#
# [1518 rows x 2 columns]

# %%
df3["Mortality outcome"]= new2[0]

# %%
df3["Blood test"]= new2[1]

# %%
df3
# Out:
#            Patient Hospital Name  Age  Gender  Body temperature  \
# 0        Patient 1         Union   81    Male              36.6
# 1        Patient 2         Union   50    Male              38.7
# 2        Patient 3         Union   65  Female              38.5
# 3        Patient 4         Union   73    Male              38.5
# 4        Patient 5         Union   64  Female              38.0
# ...            ...           ...  ...     ...               ...
# 1513  Patient 1517         Union   45  Female              38.9
# 1514  Patient 1518         Union   66  Female              36.6
# 1515  Patient 1519         Union   71  Female              36.6
# 1516  Patient 1520         Union   66  Female              36.6
# 1517  Patient 1521         Union   64  Female              36.6
#
#                                     Underlying diseases  \
# 0                           Hypertension, Thyroidectomy
# 1                                                    No
# ...

# %%
df3 = df3.drop(df3.columns[-2], axis=1)

# %%
df3
# Out:
#            Patient Hospital Name  Age  Gender  Body temperature  \
# 0        Patient 1         Union   81    Male              36.6
# 1        Patient 2         Union   50    Male              38.7
# 2        Patient 3         Union   65  Female              38.5
# 3        Patient 4         Union   73    Male              38.5
# 4        Patient 5         Union   64  Female              38.0
# ...            ...           ...  ...     ...               ...
# 1513  Patient 1517         Union   45  Female              38.9
# 1514  Patient 1518         Union   66  Female              36.6
# 1515  Patient 1519         Union   71  Female              36.6
# 1516  Patient 1520         Union   66  Female              36.6
# 1517  Patient 1521         Union   64  Female              36.6
#
#                                     Underlying diseases  \
# 0                           Hypertension, Thyroidectomy
# 1                                                    No
# ...

# %%
df3.rename(columns={344 : df3.loc[0, 343]})
# Out:
#            Patient Hospital Name  Age  Gender  Body temperature  \
# 0        Patient 1         Union   81    Male              36.6
# 1        Patient 2         Union   50    Male              38.7
# 2        Patient 3         Union   65  Female              38.5
# 3        Patient 4         Union   73    Male              38.5
# 4        Patient 5         Union   64  Female              38.0
# ...            ...           ...  ...     ...               ...
# 1513  Patient 1517         Union   45  Female              38.9
# 1514  Patient 1518         Union   66  Female              36.6
# 1515  Patient 1519         Union   71  Female              36.6
# 1516  Patient 1520         Union   66  Female              36.6
# 1517  Patient 1521         Union   64  Female              36.6
#
#                                     Underlying diseases  \
# 0                           Hypertension, Thyroidectomy
# 1                                                    No
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
df3.head()
# Out:
#      Patient Hospital Name  Age  Gender  Body temperature  \
# 0  Patient 1         Union   81    Male              36.6
# 1  Patient 2         Union   50    Male              38.7
# 2  Patient 3         Union   65  Female              38.5
# 3  Patient 4         Union   73    Male              38.5
# 4  Patient 5         Union   64  Female              38.0
#
#              Underlying diseases SARS-CoV-2 nucleic acids  \
# 0    Hypertension, Thyroidectomy                 Positive
# 1                             No                 Positive
# 2  Postoperative cervical cancer                 Positive
# 3            Aorta calcification                 Positive
# 4                             No                 Positive
#
#   Computed tomography (CT) Morbidity outcome Mortality outcome  \
# 0                 Positive           Regular             Cured
# 1                 Positive           Regular             Cured
# 2                 Positive           Regular             Cured
# ...

# %%
#while counter < 346:
    #df3.drop(columns=[counter], inplace=True)
    #df3.rename(columns={counter+2 : df3.loc[0, counter+1]}, inplace=True)
    #df3.rename(columns={counter+3 : df3.loc[0, f'{counter+1} Normal Range']}, inplace=True)
    #df3.drop(columns=[counter+1], inplace=True)
    #counter += 4

# %%
new_name = df3.loc[0, 10]

# %%
new_name
# Out:
# 'MCHC'

# %%
counter = 9
while counter < 346:
    first = counter
    second = counter + 1
    third = counter + 2
    fourth = counter + 3
    
    new_name = df3.loc[0, second]
    df3.rename(columns = {third : new_name, fourth : f'{new_name} Normal Range'}, inplace = True)
    df3.drop(columns = [first, second], inplace = True)
    counter += 4

# %%
df3.head()
# Out:
#      Patient Hospital Name  Age  Gender  Body temperature  \
# 0  Patient 1         Union   81    Male              36.6
# 1  Patient 2         Union   50    Male              38.7
# 2  Patient 3         Union   65  Female              38.5
# 3  Patient 4         Union   73    Male              38.5
# 4  Patient 5         Union   64  Female              38.0
#
#              Underlying diseases SARS-CoV-2 nucleic acids  \
# 0    Hypertension, Thyroidectomy                 Positive
# 1                             No                 Positive
# 2  Postoperative cervical cancer                 Positive
# 3            Aorta calcification                 Positive
# 4                             No                 Positive
#
#   Computed tomography (CT) Morbidity outcome Mortality outcome    MCHC  \
# 0                 Positive           Regular             Cured  344.00
# 1                 Positive           Regular             Cured  349.00
# ...

# %%
df3.shape
# Out:
# (1518, 179)

# %%
df3.set_index('Patient', inplace=True)

# %%
df3.head()
# Out:
#           Hospital Name  Age  Gender  Body temperature  \
# Patient
# Patient 1         Union   81    Male              36.6
# Patient 2         Union   50    Male              38.7
# Patient 3         Union   65  Female              38.5
# Patient 4         Union   73    Male              38.5
# Patient 5         Union   64  Female              38.0
#
#                      Underlying diseases SARS-CoV-2 nucleic acids  \
# Patient
# Patient 1    Hypertension, Thyroidectomy                 Positive
# Patient 2                             No                 Positive
# Patient 3  Postoperative cervical cancer                 Positive
# Patient 4            Aorta calcification                 Positive
# Patient 5                             No                 Positive
#
#           Computed tomography (CT) Morbidity outcome Mortality outcome  \
# Patient
# Patient 1                 Positive           Regular             Cured
# ...
